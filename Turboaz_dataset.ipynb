# %% [markdown]
# <a href="https://colab.research.google.com/github/kazimovmirkazim/Azerbaijani-car-dataset-Turboaz-dataset/blob/main/Turboaz_dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !unzip /content/turboaz-cars-project.zip
# Out:
# Archive:  /content/turboaz-cars-project.zip
#   inflating: cars.csv

# %%
import pandas as pd
import numpy as np

# %%
pd.set_option('display.max_columns',None)

# %%
df= pd.read_csv('/content/turboaz-cars-project.zip')
df
# Out:
#                                         id_x  \
# 0       3c234145-d57a-4ad6-9448-d43810fc3392
# 1       c74ea36f-6be1-4de4-926d-e117197dcf00
# 2       9cefceb0-024d-4581-a869-a3c2c68a9f95
# 3       459cc337-fb63-48de-9694-41554923d311
# 4       6c5ee8d8-1c6f-4fad-a694-957a4c43c25d
# ...                                      ...
# 653716  16caa803-a546-455b-81ff-bc20868c2136
# 653717  2a26a6c1-8914-4b68-abb4-1fbd12ced7bc
# 653718  feb75615-0131-4d6f-b009-cc02faea4e01
# 653719  e5f8e957-5543-42be-b30f-78723ce551f9
# 653720  a59362fe-117b-4b1c-bd43-636f1469cdbb
#
#                               car_rel_url_x                datetime_scrape  \
# 0                /autos/8748840-hyundai-i30  2024-09-13 20:32:19.751157+00
# 1       /autos/8475807-lada-vaz-niva-travel  2024-09-13 20:32:19.751157+00
# 2        /autos/8739686-toyota-land-cruiser  2024-09-13 20:32:19.751157+00
# 3            /autos/8712597-hyundai-elantra  2024-09-13 20:32:19.751157+00
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 653721 entries, 0 to 653720
# Data columns (total 56 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   id_x                      653721 non-null  object
#  1   car_rel_url_x             653721 non-null  object
#  2   datetime_scrape           653721 non-null  object
#  3   name                      653721 non-null  object
#  4   price_x                   653721 non-null  float64
#  5   currency_x                653721 non-null  object
#  6   datetime_product          653721 non-null  object
#  7   city                      653721 non-null  object
#  8   day                       653721 non-null  object
#  9   hour                      653721 non-null  object
#  10  attributes                653721 non-null  object
#  11  production_year           653721 non-null  int64
#  12  engine_displacement_num   653721 non-null  float64
# ...

# %%
df.isna().sum()
# Out:
# id_x                             0
# car_rel_url_x                    0
# datetime_scrape                  0
# name                             0
# price_x                          0
# currency_x                       0
# datetime_product                 0
# city                             0
# day                              0
# hour                             0
# attributes                       0
# production_year                  0
# engine_displacement_num          0
# engine_displacement_unit      5788
# kilometrage_num                  0
# kilometrage_unit              5788
# barter                      428168
# loan                        490381
# salon                       460382
# spare_parts                 651959
# vip                         364780
# featured                    489886
# img_url                          0
# id_y                             0
# cars_id                          0
# car_rel_url_y                    0
# datetime                         0
# ...

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.corr(numeric_only=True)
# Out:
#                           price_x  production_year  engine_displacement_num  \
# price_x                  1.000000        -0.035643                 0.251424
# production_year         -0.035643         1.000000                 0.160363
# engine_displacement_num  0.251424         0.160363                 1.000000
# kilometrage_num         -0.320819         0.076193                 0.283803
# price_y                  0.999996        -0.035643                 0.251427
# phone                   -0.189792         0.028604                 0.008800
# views                    0.116689        -0.071719                -0.058776
# Buraxılış ili            0.458604        -0.072832                -0.149604
#
#                          kilometrage_num   price_y     phone     views  \
# price_x                        -0.320819  0.999996 -0.189792  0.116689
# production_year                 0.076193 -0.035643  0.028604 -0.071719
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 653721 entries, 0 to 653720
# Data columns (total 56 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   id_x                      653721 non-null  object
#  1   car_rel_url_x             653721 non-null  object
#  2   datetime_scrape           653721 non-null  object
#  3   name                      653721 non-null  object
#  4   price_x                   653721 non-null  float64
#  5   currency_x                653721 non-null  object
#  6   datetime_product          653721 non-null  object
#  7   city                      653721 non-null  object
#  8   day                       653721 non-null  object
#  9   hour                      653721 non-null  object
#  10  attributes                653721 non-null  object
#  11  production_year           653721 non-null  int64
#  12  engine_displacement_num   653721 non-null  float64
# ...

# %%
df
# Out:
#                                         id_x  \
# 0       3c234145-d57a-4ad6-9448-d43810fc3392
# 1       c74ea36f-6be1-4de4-926d-e117197dcf00
# 2       9cefceb0-024d-4581-a869-a3c2c68a9f95
# 3       459cc337-fb63-48de-9694-41554923d311
# 4       6c5ee8d8-1c6f-4fad-a694-957a4c43c25d
# ...                                      ...
# 653716  16caa803-a546-455b-81ff-bc20868c2136
# 653717  2a26a6c1-8914-4b68-abb4-1fbd12ced7bc
# 653718  feb75615-0131-4d6f-b009-cc02faea4e01
# 653719  e5f8e957-5543-42be-b30f-78723ce551f9
# 653720  a59362fe-117b-4b1c-bd43-636f1469cdbb
#
#                               car_rel_url_x                datetime_scrape  \
# 0                /autos/8748840-hyundai-i30  2024-09-13 20:32:19.751157+00
# 1       /autos/8475807-lada-vaz-niva-travel  2024-09-13 20:32:19.751157+00
# 2        /autos/8739686-toyota-land-cruiser  2024-09-13 20:32:19.751157+00
# 3            /autos/8712597-hyundai-elantra  2024-09-13 20:32:19.751157+00
# ...

# %%
display(df['currency_x'].unique())
# Out:
# array(['AZN', '$', '€'], dtype=object)

# %%
display(df['currency_y'].unique())
# Out:
# array(['AZN', 'USD', 'EUR'], dtype=object)

# %%
df.drop('id_x', axis=1, inplace=True)
display(df.head())
# Out:
#                          car_rel_url_x                datetime_scrape  \
# 0           /autos/8748840-hyundai-i30  2024-09-13 20:32:19.751157+00
# 1  /autos/8475807-lada-vaz-niva-travel  2024-09-13 20:32:19.751157+00
# 2   /autos/8739686-toyota-land-cruiser  2024-09-13 20:32:19.751157+00
# 3       /autos/8712597-hyundai-elantra  2024-09-13 20:32:19.751157+00
# 4          /autos/8674773-toyota-prius  2024-09-13 20:32:19.751157+00
#
#                      name  price_x currency_x   datetime_product  city  \
# 0             Hyundai i30  15000.0        AZN  Bakı, dünən 23:28  bakı
# 1  LADA (VAZ) Niva Travel  23700.0        AZN  Bakı, dünən 23:59  bakı
# 2     Toyota Land Cruiser  35600.0          $  Bakı, dünən 23:59  bakı
# 3         Hyundai Elantra  26700.0        AZN  Bakı, dünən 23:59  bakı
# 4            Toyota Prius  10500.0        AZN  Bakı, dünən 23:59  bakı
#
#           day   hour               attributes  production_year  \
# ...

# %%
df.drop('car_rel_url_y', axis=1, inplace=True)
display(df.head())
# Out:
#                          car_rel_url_x                datetime_scrape  \
# 0           /autos/8748840-hyundai-i30  2024-09-13 20:32:19.751157+00
# 1  /autos/8475807-lada-vaz-niva-travel  2024-09-13 20:32:19.751157+00
# 2   /autos/8739686-toyota-land-cruiser  2024-09-13 20:32:19.751157+00
# 3       /autos/8712597-hyundai-elantra  2024-09-13 20:32:19.751157+00
# 4          /autos/8674773-toyota-prius  2024-09-13 20:32:19.751157+00
#
#                      name  price_x currency_x   datetime_product  city  \
# 0             Hyundai i30  15000.0        AZN  Bakı, dünən 23:28  bakı
# 1  LADA (VAZ) Niva Travel  23700.0        AZN  Bakı, dünən 23:59  bakı
# 2     Toyota Land Cruiser  35600.0          $  Bakı, dünən 23:59  bakı
# 3         Hyundai Elantra  26700.0        AZN  Bakı, dünən 23:59  bakı
# 4            Toyota Prius  10500.0        AZN  Bakı, dünən 23:59  bakı
#
#           day   hour               attributes  production_year  \
# ...

# %%
df.drop('car_rel_url_x', axis=1, inplace=True)
display(df.head())
# Out:
#                  datetime_scrape                    name  price_x currency_x  \
# 0  2024-09-13 20:32:19.751157+00             Hyundai i30  15000.0        AZN
# 1  2024-09-13 20:32:19.751157+00  LADA (VAZ) Niva Travel  23700.0        AZN
# 2  2024-09-13 20:32:19.751157+00     Toyota Land Cruiser  35600.0          $
# 3  2024-09-13 20:32:19.751157+00         Hyundai Elantra  26700.0        AZN
# 4  2024-09-13 20:32:19.751157+00            Toyota Prius  10500.0        AZN
#
#     datetime_product  city         day   hour               attributes  \
# 0  Bakı, dünən 23:28  bakı  13.09.2024  23:28  2008, 1.6 L, 270 000 km
# 1  Bakı, dünən 23:59  bakı  13.09.2024  23:59        2024, 1.7 L, 0 km
# 2  Bakı, dünən 23:59  bakı  13.09.2024  23:59  2011, 4.0 L, 164 750 km
# 3  Bakı, dünən 23:59  bakı  13.09.2024  23:59  2018, 2.0 L, 126 000 km
# 4  Bakı, dünən 23:59  bakı  13.09.2024  23:59  2007, 1.5 L, 354 000 km
#
#    production_year  engine_displacement_num engine_displacement_unit  \
# ...

# %%
df.drop('datetime_product', axis=1, inplace=True)
display(df.head())
# Out:
#                  datetime_scrape                    name  price_x currency_x  \
# 0  2024-09-13 20:32:19.751157+00             Hyundai i30  15000.0        AZN
# 1  2024-09-13 20:32:19.751157+00  LADA (VAZ) Niva Travel  23700.0        AZN
# 2  2024-09-13 20:32:19.751157+00     Toyota Land Cruiser  35600.0          $
# 3  2024-09-13 20:32:19.751157+00         Hyundai Elantra  26700.0        AZN
# 4  2024-09-13 20:32:19.751157+00            Toyota Prius  10500.0        AZN
#
#    city         day   hour               attributes  production_year  \
# 0  bakı  13.09.2024  23:28  2008, 1.6 L, 270 000 km             2008
# 1  bakı  13.09.2024  23:59        2024, 1.7 L, 0 km             2024
# 2  bakı  13.09.2024  23:59  2011, 4.0 L, 164 750 km             2011
# 3  bakı  13.09.2024  23:59  2018, 2.0 L, 126 000 km             2018
# 4  bakı  13.09.2024  23:59  2007, 1.5 L, 354 000 km             2007
#
#    engine_displacement_num engine_displacement_unit  kilometrage_num  \
# ...

# %%
df.drop('datetime_scrape', axis=1, inplace=True)
display(df.head())
# Out:
#                      name  price_x currency_x  city         day   hour  \
# 0             Hyundai i30  15000.0        AZN  bakı  13.09.2024  23:28
# 1  LADA (VAZ) Niva Travel  23700.0        AZN  bakı  13.09.2024  23:59
# 2     Toyota Land Cruiser  35600.0          $  bakı  13.09.2024  23:59
# 3         Hyundai Elantra  26700.0        AZN  bakı  13.09.2024  23:59
# 4            Toyota Prius  10500.0        AZN  bakı  13.09.2024  23:59
#
#                 attributes  production_year  engine_displacement_num  \
# 0  2008, 1.6 L, 270 000 km             2008                      1.6
# 1        2024, 1.7 L, 0 km             2024                      1.7
# 2  2011, 4.0 L, 164 750 km             2011                      4.0
# 3  2018, 2.0 L, 126 000 km             2018                      2.0
# 4  2007, 1.5 L, 354 000 km             2007                      1.5
#
#   engine_displacement_unit  kilometrage_num kilometrage_unit barter loan  \
# ...

# %%
df.drop('attributes', axis=1, inplace=True)
display(df.head())
# Out:
#                      name  price_x currency_x  city         day   hour  \
# 0             Hyundai i30  15000.0        AZN  bakı  13.09.2024  23:28
# 1  LADA (VAZ) Niva Travel  23700.0        AZN  bakı  13.09.2024  23:59
# 2     Toyota Land Cruiser  35600.0          $  bakı  13.09.2024  23:59
# 3         Hyundai Elantra  26700.0        AZN  bakı  13.09.2024  23:59
# 4            Toyota Prius  10500.0        AZN  bakı  13.09.2024  23:59
#
#    production_year  engine_displacement_num engine_displacement_unit  \
# 0             2008                      1.6                        L
# 1             2024                      1.7                        L
# 2             2011                      4.0                        L
# 3             2018                      2.0                        L
# 4             2007                      1.5                        L
#
#    kilometrage_num kilometrage_unit barter loan  salon spare_parts  \
# ...

# %%
df.drop('img_url', axis=1, inplace=True)
display(df.head())
# Out:
#                      name  price_x currency_x  city         day   hour  \
# 0             Hyundai i30  15000.0        AZN  bakı  13.09.2024  23:28
# 1  LADA (VAZ) Niva Travel  23700.0        AZN  bakı  13.09.2024  23:59
# 2     Toyota Land Cruiser  35600.0          $  bakı  13.09.2024  23:59
# 3         Hyundai Elantra  26700.0        AZN  bakı  13.09.2024  23:59
# 4            Toyota Prius  10500.0        AZN  bakı  13.09.2024  23:59
#
#    production_year  engine_displacement_num engine_displacement_unit  \
# 0             2008                      1.6                        L
# 1             2024                      1.7                        L
# 2             2011                      4.0                        L
# 3             2018                      2.0                        L
# 4             2007                      1.5                        L
#
#    kilometrage_num kilometrage_unit barter loan  salon spare_parts  \
# ...

# %%
df.drop('id_y', axis=1, inplace=True)
display(df.head())
# Out:
#                      name  price_x currency_x  city         day   hour  \
# 0             Hyundai i30  15000.0        AZN  bakı  13.09.2024  23:28
# 1  LADA (VAZ) Niva Travel  23700.0        AZN  bakı  13.09.2024  23:59
# 2     Toyota Land Cruiser  35600.0          $  bakı  13.09.2024  23:59
# 3         Hyundai Elantra  26700.0        AZN  bakı  13.09.2024  23:59
# 4            Toyota Prius  10500.0        AZN  bakı  13.09.2024  23:59
#
#    production_year  engine_displacement_num engine_displacement_unit  \
# 0             2008                      1.6                        L
# 1             2024                      1.7                        L
# 2             2011                      4.0                        L
# 3             2018                      2.0                        L
# 4             2007                      1.5                        L
#
#    kilometrage_num kilometrage_unit barter loan  salon spare_parts  \
# ...

# %%
df.drop('cars_id', axis=1, inplace=True)
display(df.head())
# Out:
#                      name  price_x currency_x  city         day   hour  \
# 0             Hyundai i30  15000.0        AZN  bakı  13.09.2024  23:28
# 1  LADA (VAZ) Niva Travel  23700.0        AZN  bakı  13.09.2024  23:59
# 2     Toyota Land Cruiser  35600.0          $  bakı  13.09.2024  23:59
# 3         Hyundai Elantra  26700.0        AZN  bakı  13.09.2024  23:59
# 4            Toyota Prius  10500.0        AZN  bakı  13.09.2024  23:59
#
#    production_year  engine_displacement_num engine_displacement_unit  \
# 0             2008                      1.6                        L
# 1             2024                      1.7                        L
# 2             2011                      4.0                        L
# 3             2018                      2.0                        L
# 4             2007                      1.5                        L
#
#    kilometrage_num kilometrage_unit barter loan  salon spare_parts  \
# ...

# %%
df.drop('owner_name', axis=1, inplace=True)
display(df.head())
# Out:
#                      name  price_x currency_x  city         day   hour  \
# 0             Hyundai i30  15000.0        AZN  bakı  13.09.2024  23:28
# 1  LADA (VAZ) Niva Travel  23700.0        AZN  bakı  13.09.2024  23:59
# 2     Toyota Land Cruiser  35600.0          $  bakı  13.09.2024  23:59
# 3         Hyundai Elantra  26700.0        AZN  bakı  13.09.2024  23:59
# 4            Toyota Prius  10500.0        AZN  bakı  13.09.2024  23:59
#
#    production_year  engine_displacement_num engine_displacement_unit  \
# 0             2008                      1.6                        L
# 1             2024                      1.7                        L
# 2             2011                      4.0                        L
# 3             2018                      2.0                        L
# 4             2007                      1.5                        L
#
#    kilometrage_num kilometrage_unit barter loan  salon spare_parts  \
# ...

# %%
df.drop('car_details_id_x', axis=1, inplace=True)
display(df.head())
# Out:
#                      name  price_x currency_x  city         day   hour  \
# 0             Hyundai i30  15000.0        AZN  bakı  13.09.2024  23:28
# 1  LADA (VAZ) Niva Travel  23700.0        AZN  bakı  13.09.2024  23:59
# 2     Toyota Land Cruiser  35600.0          $  bakı  13.09.2024  23:59
# 3         Hyundai Elantra  26700.0        AZN  bakı  13.09.2024  23:59
# 4            Toyota Prius  10500.0        AZN  bakı  13.09.2024  23:59
#
#    production_year  engine_displacement_num engine_displacement_unit  \
# 0             2008                      1.6                        L
# 1             2024                      1.7                        L
# 2             2011                      4.0                        L
# 3             2018                      2.0                        L
# 4             2007                      1.5                        L
#
#    kilometrage_num kilometrage_unit barter loan  salon spare_parts  \
# ...

# %%
df.drop('datetime', axis=1, inplace=True)
display(df.head())
# Out:
#                      name  price_x currency_x  city         day   hour  \
# 0             Hyundai i30  15000.0        AZN  bakı  13.09.2024  23:28
# 1  LADA (VAZ) Niva Travel  23700.0        AZN  bakı  13.09.2024  23:59
# 2     Toyota Land Cruiser  35600.0          $  bakı  13.09.2024  23:59
# 3         Hyundai Elantra  26700.0        AZN  bakı  13.09.2024  23:59
# 4            Toyota Prius  10500.0        AZN  bakı  13.09.2024  23:59
#
#    production_year  engine_displacement_num engine_displacement_unit  \
# 0             2008                      1.6                        L
# 1             2024                      1.7                        L
# 2             2011                      4.0                        L
# 3             2018                      2.0                        L
# 4             2007                      1.5                        L
#
#    kilometrage_num kilometrage_unit barter loan  salon spare_parts  \
# ...

# %%
df.drop('description', axis=1, inplace=True)
display(df.head())
# Out:
#                      name  price_x currency_x  city         day   hour  \
# 0             Hyundai i30  15000.0        AZN  bakı  13.09.2024  23:28
# 1  LADA (VAZ) Niva Travel  23700.0        AZN  bakı  13.09.2024  23:59
# 2     Toyota Land Cruiser  35600.0          $  bakı  13.09.2024  23:59
# 3         Hyundai Elantra  26700.0        AZN  bakı  13.09.2024  23:59
# 4            Toyota Prius  10500.0        AZN  bakı  13.09.2024  23:59
#
#    production_year  engine_displacement_num engine_displacement_unit  \
# 0             2008                      1.6                        L
# 1             2024                      1.7                        L
# 2             2011                      4.0                        L
# 3             2018                      2.0                        L
# 4             2007                      1.5                        L
#
#    kilometrage_num kilometrage_unit barter loan  salon spare_parts  \
# ...

# %%
df.drop('updated', axis=1, inplace=True)
display(df.head())
# Out:
#                      name  price_x currency_x  city         day   hour  \
# 0             Hyundai i30  15000.0        AZN  bakı  13.09.2024  23:28
# 1  LADA (VAZ) Niva Travel  23700.0        AZN  bakı  13.09.2024  23:59
# 2     Toyota Land Cruiser  35600.0          $  bakı  13.09.2024  23:59
# 3         Hyundai Elantra  26700.0        AZN  bakı  13.09.2024  23:59
# 4            Toyota Prius  10500.0        AZN  bakı  13.09.2024  23:59
#
#    production_year  engine_displacement_num engine_displacement_unit  \
# 0             2008                      1.6                        L
# 1             2024                      1.7                        L
# 2             2011                      4.0                        L
# 3             2018                      2.0                        L
# 4             2007                      1.5                        L
#
#    kilometrage_num kilometrage_unit barter loan  salon spare_parts  \
# ...

# %%
df['featured'].unique()
# Out:
# array([nan, 'featured-icon'], dtype=object)

# %%
df['featured'].value_counts()
# Out:
# featured
# featured-icon    163835
# Name: count, dtype: int64

# %%
df['featured'].isnull().sum()
# Out:
# np.int64(489886)

# %%
df['featured'].fillna('Not Featured', inplace=True)
display(df['featured'].value_counts())
# Out:
# /tmp/ipython-input-31-3000790433.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['featured'].fillna('Not Featured', inplace=True)
# featured
# Not Featured     489886
# featured-icon    163835
# Name: count, dtype: int64

# %%
df
# Out:
#                           name   price_x currency_x      city         day  \
# 0                  Hyundai i30   15000.0        AZN      bakı  13.09.2024
# 1       LADA (VAZ) Niva Travel   23700.0        AZN      bakı  13.09.2024
# 2          Toyota Land Cruiser   35600.0          $      bakı  13.09.2024
# 3              Hyundai Elantra   26700.0        AZN      bakı  13.09.2024
# 4                 Toyota Prius   10500.0        AZN      bakı  13.09.2024
# ...                        ...       ...        ...       ...         ...
# 653716            Toyota Prius   10800.0        AZN      bakı  05.01.2025
# 653717              UAZ Hunter    9500.0        AZN    göygöl  05.01.2025
# 653718         Hyundai Elantra   25400.0        AZN      bakı  05.01.2025
# 653719     Jeep Grand Cherokee   10600.0        AZN  kürdəmir  05.01.2025
# 653720     Land Rover Defender  128500.0          $      bakı  05.01.2025
#
#          hour  production_year  engine_displacement_num  \
# ...

# %%
df1 = df.drop(['views','engine_displacement_unit','price_y','phone','name','Yürüş','car_details_id_y','car_rel_url','city','day','hour','vip','vin','production_year','barter' ,'extra_info','Sahiblər'] ,axis=1,inplace=True)
df1
display(df.head())
# Out:
#    price_x currency_x  engine_displacement_num  kilometrage_num  \
# 0  15000.0        AZN                      1.6           270000
# 1  23700.0        AZN                      1.7                0
# 2  35600.0          $                      4.0           164750
# 3  26700.0        AZN                      2.0           126000
# 4  10500.0        AZN                      1.5           354000
#
#   kilometrage_unit loan  salon spare_parts       featured currency_y  \
# 0               km  NaN    NaN         NaN   Not Featured        AZN
# 1               km  NaN  Salon         NaN  featured-icon        AZN
# 2               km  NaN    NaN         NaN  featured-icon        USD
# 3               km  NaN    NaN         NaN   Not Featured        AZN
# 4               km  NaN    NaN         NaN   Not Featured        AZN
#
#          shop_name                 Ban növü  Buraxılış ili  \
# 0              NaN          Hetçbek, 5 qapı           2008
# ...

# %%
df
# Out:
#          price_x currency_x  engine_displacement_num  kilometrage_num  \
# 0        15000.0        AZN                      1.6           270000
# 1        23700.0        AZN                      1.7                0
# 2        35600.0          $                      4.0           164750
# 3        26700.0        AZN                      2.0           126000
# 4        10500.0        AZN                      1.5           354000
# ...          ...        ...                      ...              ...
# 653716   10800.0        AZN                      1.5           320000
# 653717    9500.0        AZN                      2.9           155000
# 653718   25400.0        AZN                      2.0            77926
# 653719   10600.0        AZN                      4.7           250000
# 653720  128500.0          $                      3.0            19000
#
#        kilometrage_unit loan  salon spare_parts       featured currency_y  \
# ...

# %%
df['Hansı bazar üçün yığılıb']
# Out:
# 0                 NaN
# 1         Rəsmi diler
# 2         Rəsmi diler
# 3                 NaN
# 4             Amerika
#              ...
# 653716            NaN
# 653717            NaN
# 653718            NaN
# 653719        Amerika
# 653720    Rəsmi diler
# Name: Hansı bazar üçün yığılıb, Length: 653721, dtype: object

# %%
df['Hansı bazar üçün yığılıb'] = df['Hansı bazar üçün yığılıb'].fillna('Digər')

# %%
df['Hansı bazar üçün yığılıb'].unique()
# Out:
# array(['Digər', 'Rəsmi diler', 'Amerika', 'Dubay', 'Rusiya', 'Çin',
#        'Avropa', 'Yaponiya', 'Koreya'], dtype=object)

# %%
df['Hansı bazar üçün yığılıb'] = df['Hansı bazar üçün yığılıb'].replace('Naməlum', 'Digər')

# %%
df['Hansı bazar üçün yığılıb'].unique()
# Out:
# array(['Digər', 'Rəsmi diler', 'Amerika', 'Dubay', 'Rusiya', 'Çin',
#        'Avropa', 'Yaponiya', 'Koreya'], dtype=object)

# %%
df['Yerlərin sayı'].unique()
# Out:
# array(['5', '8+', nan, '3', '7', '2', '4', '6', '1'], dtype=object)

# %%
df['Yerlərin sayı'] = df['Yerlərin sayı'].fillna('Digər')

# %%
df['Yerlərin sayı'].unique()
# Out:
# array(['5', '8+', 'Digər', '3', '7', '2', '4', '6', '1'], dtype=object)

# %%
df['Yerlərin sayı'] = df['Yerlərin sayı'].replace('Digər', '-1')

# %%
df['Yerlərin sayı'].unique()
# Out:
# array(['5', '8+', '-1', '3', '7', '2', '4', '6', '1'], dtype=object)

# %%
df['Yerlərin sayı']
# Out:
# 0          5
# 1          5
# 2         8+
# 3         -1
# 4          5
#           ..
# 653716     5
# 653717    -1
# 653718     5
# 653719     5
# 653720     5
# Name: Yerlərin sayı, Length: 653721, dtype: object

# %%
df
# Out:
#          price_x currency_x  engine_displacement_num  kilometrage_num  \
# 0        15000.0        AZN                      1.6           270000
# 1        23700.0        AZN                      1.7                0
# 2        35600.0          $                      4.0           164750
# 3        26700.0        AZN                      2.0           126000
# 4        10500.0        AZN                      1.5           354000
# ...          ...        ...                      ...              ...
# 653716   10800.0        AZN                      1.5           320000
# 653717    9500.0        AZN                      2.9           155000
# 653718   25400.0        AZN                      2.0            77926
# 653719   10600.0        AZN                      4.7           250000
# 653720  128500.0          $                      3.0            19000
#
#        kilometrage_unit loan  salon spare_parts       featured currency_y  \
# ...

# %%
df['salon'].unique()
# Out:
# array([nan, 'Salon'], dtype=object)

# %%
df1 = df.drop(['shop_name'] ,axis=1,inplace=True)
df1

# %%
df
# Out:
#          price_x currency_x  engine_displacement_num  kilometrage_num  \
# 0        15000.0        AZN                      1.6           270000
# 1        23700.0        AZN                      1.7                0
# 2        35600.0          $                      4.0           164750
# 3        26700.0        AZN                      2.0           126000
# 4        10500.0        AZN                      1.5           354000
# ...          ...        ...                      ...              ...
# 653716   10800.0        AZN                      1.5           320000
# 653717    9500.0        AZN                      2.9           155000
# 653718   25400.0        AZN                      2.0            77926
# 653719   10600.0        AZN                      4.7           250000
# 653720  128500.0          $                      3.0            19000
#
#        kilometrage_unit loan  salon spare_parts       featured currency_y  \
# ...

# %%
df['Qəzalı'].unique()
# Out:
# array([nan, 'Bəli'], dtype=object)

# %%
df['Qəzalı']= df['Qəzalı'].fillna('xeyr')

# %%
df['Qəzalı'].unique()
# Out:
# array(['xeyr', 'Bəli'], dtype=object)

# %%
df['Qəzalı']= df['Qəzalı'].replace('xeyr','Xeyr')

# %%
df['Qəzalı'].unique()
# Out:
# array(['Xeyr', 'Bəli'], dtype=object)

# %%
df['spare_parts'].unique()
# Out:
# array([nan, 'Qəzalı'], dtype=object)

# %%
df['spare_parts'] = df['spare_parts'].fillna('Qəzasız')

# %%
df['spare_parts'].value_counts()
# Out:
# spare_parts
# Qəzasız    651959
# Qəzalı       1762
# Name: count, dtype: int64

# %%
df['Qəzalı'].value_counts()
# Out:
# Qəzalı
# Xeyr    651960
# Bəli      1761
# Name: count, dtype: int64

# %%
df['Vəziyyəti'].unique()
# Out:
# array(['Vuruğu yoxdur, rənglənməyib', 'Vuruğu yoxdur, rənglənib',
#        'Vuruğu var, rənglənib', 'Vuruğu var, rənglənməyib', nan],
#       dtype=object)

# %%
df['featured'].unique()
# Out:
# array(['Not Featured', 'featured-icon'], dtype=object)

# %%
df1 = df.drop(['featured','spare_parts'] ,axis=1,inplace=True)
df1

# %%
df['kilometrage_unit'].unique()
# Out:
# array(['km', nan], dtype=object)

# %%
df['kilometrage_unit'].value_counts()
# Out:
# kilometrage_unit
# km    647933
# Name: count, dtype: int64

# %%
df['kilometrage_unit'] = df['kilometrage_unit'].fillna('mil')

# %%
df['kilometrage_unit'].unique()
# Out:
# array(['km', 'mil'], dtype=object)

# %%
df['kilometrage_unit'].value_counts()
# Out:
# kilometrage_unit
# km     647933
# mil      5788
# Name: count, dtype: int64

# %%
pd.set_option('display.max_columns', None)
df[df['kilometrage_unit'] == 'mil']
# Out:
#         price_x currency_x  engine_displacement_num  kilometrage_num  \
# 434384  54900.0        AZN                      0.0                0
# 434385  54900.0        AZN                      0.0                0
# 434386  54900.0        AZN                      0.0                0
# 434387  54900.0        AZN                      0.0                0
# 434572  28900.0          $                      0.0                0
# ...         ...        ...                      ...              ...
# 653355    650.0        AZN                      0.0                0
# 653411  42600.0          $                      0.0                0
# 653485  38900.0        AZN                      0.0                0
# 653604   3000.0        AZN                      0.0                0
# 653664  45000.0          $                      0.0                0
#
#        kilometrage_unit         loan  salon currency_y  \
# 434384              mil  Kreditdədir  Salon        AZN
# ...

# %%
df
# Out:
#          price_x currency_x  engine_displacement_num  kilometrage_num  \
# 0        15000.0        AZN                      1.6           270000
# 1        23700.0        AZN                      1.7                0
# 2        35600.0          $                      4.0           164750
# 3        26700.0        AZN                      2.0           126000
# 4        10500.0        AZN                      1.5           354000
# ...          ...        ...                      ...              ...
# 653716   10800.0        AZN                      1.5           320000
# 653717    9500.0        AZN                      2.9           155000
# 653718   25400.0        AZN                      2.0            77926
# 653719   10600.0        AZN                      4.7           250000
# 653720  128500.0          $                      3.0            19000
#
#        kilometrage_unit loan  salon currency_y                 Ban növü  \
# ...

# %%
df['kilometrage_unit'].unique()
# Out:
# array(['km', 'mil'], dtype=object)

# %%
df['Yerlərin sayı']=df['Yerlərin sayı'].replace('8+','8')

# %%
df['Yerlərin sayı']
# Out:
# 0          5
# 1          5
# 2          8
# 3         -1
# 4          5
#           ..
# 653716     5
# 653717    -1
# 653718     5
# 653719     5
# 653720     5
# Name: Yerlərin sayı, Length: 653721, dtype: object

# %%
df
# Out:
#          price_x currency_x  engine_displacement_num  kilometrage_num  \
# 0        15000.0        AZN                      1.6           270000
# 1        23700.0        AZN                      1.7                0
# 2        35600.0          $                      4.0           164750
# 3        26700.0        AZN                      2.0           126000
# 4        10500.0        AZN                      1.5           354000
# ...          ...        ...                      ...              ...
# 653716   10800.0        AZN                      1.5           320000
# 653717    9500.0        AZN                      2.9           155000
# 653718   25400.0        AZN                      2.0            77926
# 653719   10600.0        AZN                      4.7           250000
# 653720  128500.0          $                      3.0            19000
#
#        kilometrage_unit loan  salon currency_y                 Ban növü  \
# ...

# %%
df1 = df.drop(['kilometrage_unit'] ,axis=1,inplace=True)
df1

# %%
df['salon']= df['salon'].fillna('Digər')

# %%
df['salon']= df['salon'].replace('digər','Digər')

# %%
df
# Out:
#          price_x currency_x  engine_displacement_num  kilometrage_num loan  \
# 0        15000.0        AZN                      1.6           270000  NaN
# 1        23700.0        AZN                      1.7                0  NaN
# 2        35600.0          $                      4.0           164750  NaN
# 3        26700.0        AZN                      2.0           126000  NaN
# 4        10500.0        AZN                      1.5           354000  NaN
# ...          ...        ...                      ...              ...  ...
# 653716   10800.0        AZN                      1.5           320000  NaN
# 653717    9500.0        AZN                      2.9           155000  NaN
# 653718   25400.0        AZN                      2.0            77926  NaN
# 653719   10600.0        AZN                      4.7           250000  NaN
# 653720  128500.0          $                      3.0            19000  NaN
#
#         salon currency_y                 Ban növü  Buraxılış ili  \
# ...

# %%
df['currency_x'].unique()
# Out:
# array(['AZN', '$', '€'], dtype=object)

# %%
df['currency_x'].unique()
# Out:
# array(['AZN', '$', '€'], dtype=object)

# %%
currency_rates = {
    'AZN': 1.00,
    '$': 1.70,
    '€': 1.95
}

df['qiymet_azn'] = df['price_x'] * df['currency_x'].map(currency_rates)

# %%
df
# Out:
#          price_x currency_x  engine_displacement_num  kilometrage_num loan  \
# 0        15000.0        AZN                      1.6           270000  NaN
# 1        23700.0        AZN                      1.7                0  NaN
# 2        35600.0          $                      4.0           164750  NaN
# 3        26700.0        AZN                      2.0           126000  NaN
# 4        10500.0        AZN                      1.5           354000  NaN
# ...          ...        ...                      ...              ...  ...
# 653716   10800.0        AZN                      1.5           320000  NaN
# 653717    9500.0        AZN                      2.9           155000  NaN
# 653718   25400.0        AZN                      2.0            77926  NaN
# 653719   10600.0        AZN                      4.7           250000  NaN
# 653720  128500.0          $                      3.0            19000  NaN
#
#         salon currency_y                 Ban növü  Buraxılış ili  \
# ...

# %%
df1 = df.drop(['currency_x','currency_y'	,'price_x'] ,axis=1,inplace=True)
df1

# %%
df
# Out:
#         engine_displacement_num  kilometrage_num loan  salon  \
# 0                           1.6           270000  NaN  Digər
# 1                           1.7                0  NaN  Salon
# 2                           4.0           164750  NaN  Digər
# 3                           2.0           126000  NaN  Digər
# 4                           1.5           354000  NaN  Digər
# ...                         ...              ...  ...    ...
# 653716                      1.5           320000  NaN  Digər
# 653717                      2.9           155000  NaN  Digər
# 653718                      2.0            77926  NaN  Digər
# 653719                      4.7           250000  NaN  Digər
# 653720                      3.0            19000  NaN  Salon
#
#                        Ban növü  Buraxılış ili Hansı bazar üçün yığılıb  \
# 0               Hetçbek, 5 qapı           2008                    Digər
# 1       Offroader / SUV, 5 qapı           2024              Rəsmi diler
# ...

# %%
import pandas as pd


pattern = r'(?P<engine_volume>\d+(?:\.\d+)?)\s*L\s*/\s*(?P<horsepower>\d+)\s*a\.g\.\s*/\s*(?P<fuel_type>\w+)'
extracted_data = df['Mühərrik'].str.extract(pattern)
extracted_data['horsepower'] = extracted_data['horsepower'].fillna('-1')

df[['engine_volume', 'horsepower', 'yanacaq_novu']] = extracted_data

df['engine_volume'] = df['engine_volume'].astype(float)
df['horsepower'] = df['horsepower'].astype(int)

# %%
df
# Out:
#         engine_displacement_num  kilometrage_num loan  salon  \
# 0                           1.6           270000  NaN  Digər
# 1                           1.7                0  NaN  Salon
# 2                           4.0           164750  NaN  Digər
# 3                           2.0           126000  NaN  Digər
# 4                           1.5           354000  NaN  Digər
# ...                         ...              ...  ...    ...
# 653716                      1.5           320000  NaN  Digər
# 653717                      2.9           155000  NaN  Digər
# 653718                      2.0            77926  NaN  Digər
# 653719                      4.7           250000  NaN  Digər
# 653720                      3.0            19000  NaN  Salon
#
#                        Ban növü  Buraxılış ili Hansı bazar üçün yığılıb  \
# 0               Hetçbek, 5 qapı           2008                    Digər
# 1       Offroader / SUV, 5 qapı           2024              Rəsmi diler
# ...

# %%
df1 = df.drop(['Mühərrik','horsepower'	,'engine_volume'] ,axis=1,inplace=True)
df1

# %%
df
# Out:
#         engine_displacement_num  kilometrage_num loan  salon  \
# 0                           1.6           270000  NaN  Digər
# 1                           1.7                0  NaN  Salon
# 2                           4.0           164750  NaN  Digər
# 3                           2.0           126000  NaN  Digər
# 4                           1.5           354000  NaN  Digər
# ...                         ...              ...  ...    ...
# 653716                      1.5           320000  NaN  Digər
# 653717                      2.9           155000  NaN  Digər
# 653718                      2.0            77926  NaN  Digər
# 653719                      4.7           250000  NaN  Digər
# 653720                      3.0            19000  NaN  Salon
#
#                        Ban növü  Buraxılış ili Hansı bazar üçün yığılıb  \
# 0               Hetçbek, 5 qapı           2008                    Digər
# 1       Offroader / SUV, 5 qapı           2024              Rəsmi diler
# ...

# %%
pd.set_option('display.max_columns', None)
df
# Out:
#         engine_displacement_num  kilometrage_num loan  salon  \
# 0                           1.6           270000  NaN  Digər
# 1                           1.7                0  NaN  Salon
# 2                           4.0           164750  NaN  Digər
# 3                           2.0           126000  NaN  Digər
# 4                           1.5           354000  NaN  Digər
# ...                         ...              ...  ...    ...
# 653716                      1.5           320000  NaN  Digər
# 653717                      2.9           155000  NaN  Digər
# 653718                      2.0            77926  NaN  Digər
# 653719                      4.7           250000  NaN  Digər
# 653720                      3.0            19000  NaN  Salon
#
#                        Ban növü  Buraxılış ili Hansı bazar üçün yığılıb  \
# 0               Hetçbek, 5 qapı           2008                    Digər
# 1       Offroader / SUV, 5 qapı           2024              Rəsmi diler
# ...

# %%
df['Ban növü'].unique()
# Out:
# array(['Hetçbek, 5 qapı', 'Offroader / SUV, 5 qapı', 'Sedan', 'Liftbek',
#        'Yük maşını', 'Kompakt-Van', 'Furqon', 'Minivan', 'Mikroavtobus',
#        'Universal, 5 qapı', 'Motosiklet', 'Offroader / SUV, 3 qapı',
#        'SUV Kupe', 'Kupe', 'Pikap, ikiqat kabin', 'Hetçbek, 3 qapı',
#        'Hetçbek, 4 qapı', 'Dartqı', 'Kabriolet', 'Kvadrosikl', 'Limuzin',
#        'Universal, 3 qapı', 'Avtobus', 'Rodster', 'Offroader / SUV, açıq',
#        'Moped', 'Pikap, tək kabin', 'Karvan', 'Van', 'Mikrovan',
#        'Pikap, bir yarım kabin', 'Tarqa', 'Fastbek', 'Fayton', 'Spidster',
#        'Qolfkar'], dtype=object)

# %%
df
# Out:
#         engine_displacement_num  kilometrage_num loan  salon  \
# 0                           1.6           270000  NaN  Digər
# 1                           1.7                0  NaN  Salon
# 2                           4.0           164750  NaN  Digər
# 3                           2.0           126000  NaN  Digər
# 4                           1.5           354000  NaN  Digər
# ...                         ...              ...  ...    ...
# 653716                      1.5           320000  NaN  Digər
# 653717                      2.9           155000  NaN  Digər
# 653718                      2.0            77926  NaN  Digər
# 653719                      4.7           250000  NaN  Digər
# 653720                      3.0            19000  NaN  Salon
#
#                        Ban növü  Buraxılış ili Hansı bazar üçün yığılıb  \
# 0               Hetçbek, 5 qapı           2008                    Digər
# 1       Offroader / SUV, 5 qapı           2024              Rəsmi diler
# ...

# %%
  df['engine_displacement_num'].unique()
# Out:
# array([1.6e+00, 1.7e+00, 4.0e+00, 2.0e+00, 1.5e+00, 3.5e+00, 1.4e+00,
#        0.0e+00, 2.7e+00, 2.4e+00, 1.8e+00, 3.0e+00, 2.5e+00, 6.4e+00,
#        2.2e+00, 1.3e+00, 1.2e+00, 2.6e+00, 3.0e-01, 4.0e-01, 2.3e+00,
#        3.6e+00, 5.7e+00, 5.0e+00, 2.9e+00, 2.8e+00, 6.0e+00, 4.9e+00,
#        4.7e+00, 4.4e+00, 4.8e+00, 3.2e+00, 3.3e+00, 1.2e+01, 2.1e+00,
#        2.0e-01, 3.8e+00, 5.5e+00, 4.6e+00, 4.2e+00, 4.5e+00, 1.9e+00,
#        6.2e+00, 1.3e+01, 4.3e+00, 5.6e+00, 6.1e+00, 1.0e+00, 3.7e+00,
#        1.1e+00, 6.0e-01, 8.0e-01, 5.9e+00, 5.0e-01, 6.5e+00, 1.1e+01,
#        6.3e+00, 1.0e-01, 9.5e+00, 5.4e+00, 5.3e+00, 3.9e+00, 5.2e+00,
#        7.0e-01, 7.5e+00, 1.6e+01, 1.5e+01, 9.0e-01, 1.4e+01, 3.1e+00,
#        9.7e+00, 5.1e+00, 9.6e+00, 1.0e+01, 8.5e+00, 9.0e+00, 7.0e+00,
#        8.0e+00, 6.8e+00, 4.1e+00, 6.6e+00, 3.4e+00, 8.4e+00, 2.2e+01,
#        2.0e+01, 6.7e+00, 1.9e+01, 1.2e+02])

# %%
  df['loan'].unique()
# Out:
# array([nan, 'Kreditdədir'], dtype=object)

# %%
  df['loan'] =   df['loan'].fillna('Kreditde deyil')

# %%
  df['loan'].unique()
# Out:
# array(['Kreditde deyil', 'Kreditdədir'], dtype=object)

# %%
df
# Out:
#         engine_displacement_num  kilometrage_num            loan  salon  \
# 0                           1.6           270000  Kreditde deyil  Digər
# 1                           1.7                0  Kreditde deyil  Salon
# 2                           4.0           164750  Kreditde deyil  Digər
# 3                           2.0           126000  Kreditde deyil  Digər
# 4                           1.5           354000  Kreditde deyil  Digər
# ...                         ...              ...             ...    ...
# 653716                      1.5           320000  Kreditde deyil  Digər
# 653717                      2.9           155000  Kreditde deyil  Digər
# 653718                      2.0            77926  Kreditde deyil  Digər
# 653719                      4.7           250000  Kreditde deyil  Digər
# 653720                      3.0            19000  Kreditde deyil  Salon
#
#                        Ban növü  Buraxılış ili Hansı bazar üçün yığılıb  \
# ...

# %%
  df['Vəziyyəti'].unique()
# Out:
# array(['Vuruğu yoxdur, rənglənməyib', 'Vuruğu yoxdur, rənglənib',
#        'Vuruğu var, rənglənib', 'Vuruğu var, rənglənməyib', nan],
#       dtype=object)

# %%
  df['Vəziyyəti'] =   df['Vəziyyəti'].fillna('Bilinmir')

# %%
df['loan'].value_counts().plot(kind='pie',autopct='%1.1f%%',colormap='tab20')
# Out:
# <Axes: ylabel='count'>

# %%
df['Vəziyyəti'].value_counts().plot(kind='pie',autopct='%1.1f%%',colormap='tab20')
# Out:
# <Axes: ylabel='count'>

# %%
Q1 = df['qiymet_azn'].quantile(0.25)
Q3 = df['qiymet_azn'].quantile(0.75)
IQR = Q3 - Q1

# Alt və üst limitlər
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# Aykırı (outlier) dəyərləri tapır
outliers = df[(df['qiymet_azn'] < lower_bound) | (df['qiymet_azn'] > upper_bound)]
print(f"Outlier sayıI {outliers.shape[0]}")
# Out:
# Outlier sayıI 53880

# %%
from scipy import stats
import numpy as np

z_scores = np.abs(stats.zscore(df['qiymet_azn']))

# Z-score > 3 olanlar  sayılır
outliers = df[z_scores > 3]

# %%
df.isna().sum()
# Out:
# engine_displacement_num        0
# kilometrage_num                0
# loan                           0
# salon                          0
# Ban növü                       0
# Buraxılış ili                  0
# Hansı bazar üçün yığılıb       0
# Marka                          0
# Model                          1
# Qəzalı                         0
# Rəng                           0
# Sürətlər qutusu                0
# Vəziyyəti                      0
# Yeni                           0
# Yerlərin sayı                  0
# Ötürücü                        0
# Şəhər                          0
# qiymet_azn                     0
# yanacaq_novu                5788
# dtype: int64

# %%
  df['yanacaq_novu'].unique()
# Out:
# array(['Dizel', 'Benzin', 'Hibrid', 'Elektro', 'Plug', 'Qaz', 'Hidrogen',
#        nan], dtype=object)

# %%
df[df['yanacaq_novu'].isna()]
# Out:
#         engine_displacement_num  kilometrage_num            loan  salon  \
# 434384                      0.0                0     Kreditdədir  Salon
# 434385                      0.0                0     Kreditdədir  Salon
# 434386                      0.0                0     Kreditdədir  Salon
# 434387                      0.0                0     Kreditdədir  Salon
# 434572                      0.0                0  Kreditde deyil  Digər
# ...                         ...              ...             ...    ...
# 653355                      0.0                0  Kreditde deyil  Digər
# 653411                      0.0                0  Kreditde deyil  Digər
# 653485                      0.0                0  Kreditde deyil  Digər
# 653604                      0.0                0  Kreditde deyil  Digər
# 653664                      0.0                0  Kreditde deyil  Salon
#
#                        Ban növü  Buraxılış ili Hansı bazar üçün yığılıb  \
# ...

# %%
df
# Out:
#         engine_displacement_num  kilometrage_num            loan  salon  \
# 0                           1.6           270000  Kreditde deyil  Digər
# 1                           1.7                0  Kreditde deyil  Salon
# 2                           4.0           164750  Kreditde deyil  Digər
# 3                           2.0           126000  Kreditde deyil  Digər
# 4                           1.5           354000  Kreditde deyil  Digər
# ...                         ...              ...             ...    ...
# 653716                      1.5           320000  Kreditde deyil  Digər
# 653717                      2.9           155000  Kreditde deyil  Digər
# 653718                      2.0            77926  Kreditde deyil  Digər
# 653719                      4.7           250000  Kreditde deyil  Digər
# 653720                      3.0            19000  Kreditde deyil  Salon
#
#                        Ban növü  Buraxılış ili Hansı bazar üçün yığılıb  \
# ...

# %%
df['yanacaq_novu'] = df['yanacaq_novu'].fillna('bilinmir')

# %%
df['yanacaq_novu'].isna().sum()
# Out:
# np.int64(0)

# %%
df.rename(columns={
    'engine_displacement_num':'Muherrik Hecmi',
    'kilometrage_num' : 'Km_num',
    'loan':'Kredit',
    'salon' : 'Salon',
    'qiymet_azn': 'Qiymet_azn',
    'yanacaq_novu' : 'Yanacaq_novu'
},inplace=True)

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import accuracy_score,classification_report,roc_auc_score,confusion_matrix
import matplotlib.pyplot as plt

# %%
X= df.drop('Qiymet_azn',axis=1)
y= df['Qiymet_azn']

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2)

# %%
numeric_sutun = X_train.select_dtypes(include=np.number).columns
categoric_sutun = X_train.select_dtypes(exclude=np.number).columns

# %%
from sklearn.impute import SimpleImputer
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder,StandardScaler,MinMaxScaler
from sklearn.pipeline import Pipeline
from sklearn.metrics import mean_squared_error,mean_absolute_error

# %%
num_pipeline = Pipeline  (
    [
      ('impute',SimpleImputer(strategy='median')),
      ('scale',StandardScaler())
    ]
)

cat_pipeline = Pipeline (
    [    ('impute',SimpleImputer(strategy='most_frequent')),
        ('onehot',OneHotEncoder(handle_unknown='ignore',sparse_output=False))
    ]
)

transformer = ColumnTransformer (
    [
        ('num',num_pipeline,numeric_sutun),
        ('cat',cat_pipeline,categoric_sutun)
    ],remainder='passthrough'
)

estimator = LinearRegression()
full_pipeline = Pipeline (
    [
        ('transformer',transformer),
        ('estimator', estimator)
    ]
)

# %%
full_pipeline.fit(X_train[:7000],y_train[:7000])
# Out:
# Pipeline(steps=[('transformer',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('num',
#                                                   Pipeline(steps=[('impute',
#                                                                    SimpleImputer(strategy='median')),
#                                                                   ('scale',
#                                                                    StandardScaler())]),
#                                                   Index(['Muherrik Hecmi', 'Km_num', 'Buraxılış ili'], dtype='object')),
#                                                  ('cat',
#                                                   Pipeline(steps=[('impute',
#                                                                    SimpleImputer(strategy='most_frequent')),
#                                                                   ('onehot',
# ...

# %%
full_pipeline.score(X_test,y_test),full_pipeline.score(X_train,y_train)
# Out:
# (0.7399685727750764, 0.7274951570991601)

# %%
X_transformed=pd.DataFrame(transformer.fit_transform(X_train), columns=transformer.get_feature_names_out() )

# %%
X_transformed

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import StackingRegressor
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import RidgeCV
from sklearn.svm import SVR


estimators = [
    ('lr', RidgeCV()),
    ('rf',RandomForestRegressor(random_state=42,n_estimators=100,max_depth=12,min_samples_split=2,min_samples_leaf=1))
    # ('svr',SVR())
]
reg = StackingRegressor(
    estimators=estimators,
    final_estimator=LinearRegression()
)

# %%
# Use the existing full_pipeline and data splits
# The transformer is already defined in the full_pipeline
# Apply the transformer to the training and testing data
X_train_transformed = full_pipeline.named_steps['transformer'].transform(X_train)
X_test_transformed = full_pipeline.named_steps['transformer'].transform(X_test)

# Fit the StackingRegressor with the transformed data
reg.fit(X_train_transformed[:5000], y_train[:5000])
reg.score(X_test_transformed[:5000], y_test[:5000])
# Out:
# 0.8927047644023086

# %%
reg.score(X_train_transformed[:5000], y_train[:5000])
# Out:
# 0.9581017802487423

# %%
X_train_transformed
# Out:
# array([[ 0.72321762,  0.81485391, -1.25921177, ...,  0.        ,
#          0.        ,  0.        ],
#        [-0.17294696, -0.90374614,  1.09288493, ...,  0.        ,
#          0.        ,  0.        ],
#        [ 0.00628595,  0.93211447, -0.73652362, ...,  0.        ,
#          0.        ,  0.        ],
#        ...,
#        [ 0.00628595,  0.00868758,  0.17818066, ...,  0.        ,
#          0.        ,  0.        ],
#        [ 0.72321762, -0.99843404, -1.25921177, ...,  0.        ,
#          0.        ,  0.        ],
#        [-0.62102926,  0.41177074,  0.43952474, ...,  0.        ,
#          0.        ,  0.        ]])
